# %%
import wandb
api = wandb.Api()
run = api.run("/appliedtheta/Solen-RL-Project/4r30pbj8")

run_data = run.history()

run_data
# Out:
#          _runtime  time/total_timesteps  _step  rollout/ep_rew_mean  \
# 0       10.720071                3508.0      0           -20.500000
# 1       13.705776                7152.0      1           -20.375000
# 2       20.149830               10000.0      2                  NaN
# 3       24.194498               14821.0      4           -20.312500
# 4       27.339332               18610.0      5           -20.299999
# ..            ...                   ...    ...                  ...
# 495  15015.196033             2694042.0    701            19.840000
# 496  15060.203360             2700000.0    702                  NaN
# 497  15067.847875             2701401.0    703            19.809999
# 498  15106.514687             2708354.0    704            19.780001
# 499  15128.342529             2710000.0    705                  NaN
#
#      global_step    _timestamp  time/fps  rollout/ep_len_mean  \
# 0         3508.0  1.702903e+09    1125.0          3526.000000
# ...
