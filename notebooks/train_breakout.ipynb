# %%
from dotenv import load_dotenv

load_dotenv()

RUN_DIR = "/home/sequenzia/dev/rl-project"
ZOO_DIR = "/home/sequenzia/dev/repos/rl-baselines3-zoo/rl_zoo3"
LOG_DIR = "/home/sequenzia/dev/rl-project/trained-agents"
CONFIG_DIR = "/home/sequenzia/dev/rl-project/configs"
TENSORBOARD_DIR = "/home/sequenzia/dev/rl-project/logs/tensorboard"

ENV_ID = "BreakoutNoFrameskip-v4"
ROM = "breakout"

PROJECT_NAME = "Solen-RL-Project"

SEED = 43

SAVE_FREQ = 10000
EVAL_FREQ = 10000
EVAL_EPISODES = 5
VERBOSE = 1

CMD = f"cd {RUN_DIR} && python {ZOO_DIR}/train.py"
CMD += f" --env {ENV_ID}"
CMD += f" --log-folder {LOG_DIR}"
CMD += f" --tensorboard-log {TENSORBOARD_DIR}"
CMD += f" --wandb-project-name {PROJECT_NAME}"
CMD += f" --seed {SEED}"
CMD += f" --save-freq {SAVE_FREQ}"
CMD += f" --eval-freq {EVAL_FREQ}"
CMD += f" --eval-episodes {EVAL_EPISODES}"
CMD += f" --verbose {VERBOSE}"
CMD += f" --device cuda"
CMD += f" --track"

# %%
ALGO = "a2c"
TAGS = f"{ROM} {ALGO.upper()}"
CONFIG_PATH = f"{CONFIG_DIR}/{ALGO}.yml"
CMD = f"{CMD} --algo {ALGO} --conf {CONFIG_PATH} -tags {TAGS}"

# !{CMD}
# Out:
# ========== BreakoutNoFrameskip-v4 ==========
# Seed: 43
# wandb: Currently logged in as: appliedtheta. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.1
# wandb: Run data is saved locally in /home/sequenzia/dev/rl-project/logs/wandb/run-20231218_001433-6ww7za2q
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run BreakoutNoFrameskip-v4__a2c__43__1702876472
# wandb: ⭐️ View project at https://wandb.ai/appliedtheta/Solen-RL-Project
# wandb: 🚀 View run at https://wandb.ai/appliedtheta/Solen-RL-Project/runs/6ww7za2q
# Loading hyperparameters from: /home/sequenzia/dev/rl-project/configs/a2c.yml
# Default hyperparameters for environment (ones being tuned will be overridden):
# OrderedDict([('ent_coef', 0.01),
#              ('env_wrapper',
#               ['stable_baselines3.common.atari_wrappers.AtariWrapper']),
#              ('frame_stack', 4),
#              ('n_envs', 16),
#              ('n_timesteps', 100000.0),
#              ('policy', 'CnnPolicy'),
#              ('policy_kwargs',
#               'dict(optimizer_class=RMSpropTFLike, '
#               'optimizer_kwargs=dict(eps=1e-5))'),
#              ('vf_coef', 0.25)])
# Using 16 environments
# Creating test environment
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Using cuda device
# Log path: /home/sequenzia/dev/rl-project/trained-agents/a2c/BreakoutNoFrameskip-v4_1
# Logging to runs/BreakoutNoFrameskip-v4__a2c__43__1702876472/BreakoutNoFrameskip-v4/A2C_1
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 687      |
# |    ep_rew_mean        | 1.08     |
# | time/                 |          |
# |    fps                | 736      |
# |    iterations         | 100      |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -1.39    |
# |    explained_variance | -0.00827 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | 0.094    |
# |    value_loss         | 0.073    |
# ------------------------------------
# Eval num_timesteps=10000, episode_reward=1.20 +/- 1.17
# Episode length: 714.60 +/- 207.18
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 715      |
# |    mean_reward        | 1.2      |
# | time/                 |          |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.39    |
# |    explained_variance | -0.0431  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 124      |
# |    policy_loss        | 0.0718   |
# |    value_loss         | 0.061    |
# ------------------------------------
# New best mean reward!
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 737      |
# |    ep_rew_mean        | 1.36     |
# | time/                 |          |
# |    fps                | 753      |
# |    iterations         | 200      |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -1.39    |
# |    explained_variance | -0.0212  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | 0.0312   |
# |    value_loss         | 0.0265   |
# ------------------------------------
# Eval num_timesteps=20000, episode_reward=1.80 +/- 1.60
# Episode length: 785.20 +/- 253.42
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 785      |
# |    mean_reward        | 1.8      |
# | time/                 |          |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -1.39    |
# |    explained_variance | 0.0496   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 249      |
# |    policy_loss        | -0.0127  |
# |    value_loss         | 0.0149   |
# ------------------------------------
# New best mean reward!
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 767       |
# |    ep_rew_mean        | 1.57      |
# | time/                 |           |
# |    fps                | 769       |
# |    iterations         | 300       |
# |    time_elapsed       | 31        |
# |    total_timesteps    | 24000     |
# | train/                |           |
# |    entropy_loss       | -1.39     |
# |    explained_variance | -0.000141 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | 0.0632    |
# |    value_loss         | 0.0465    |
# -------------------------------------
# Eval num_timesteps=30000, episode_reward=1.20 +/- 0.98
# Episode length: 723.00 +/- 168.31
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 723      |
# |    mean_reward        | 1.2      |
# | time/                 |          |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -1.39    |
# |    explained_variance | -0.00285 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 374      |
# |    policy_loss        | 0.0713   |
# |    value_loss         | 0.0779   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 759      |
# |    ep_rew_mean        | 1.53     |
# | time/                 |          |
# |    fps                | 781      |
# |    iterations         | 400      |
# |    time_elapsed       | 40       |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -1.39    |
# |    explained_variance | -0.0215  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | 0.00996  |
# |    value_loss         | 0.0285   |
# ------------------------------------
# Eval num_timesteps=40000, episode_reward=1.00 +/- 1.55
# Episode length: 670.40 +/- 243.82
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 670      |
# |    mean_reward        | 1        |
# | time/                 |          |
# |    total_timesteps    | 40000    |
# | train/                |          |
# |    entropy_loss       | -1.39    |
# |    explained_variance | -0.0293  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | -0.0412  |
# |    value_loss         | 0.0197   |
# ------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 746      |
# |    ep_rew_mean     | 1.41     |
# | time/              |          |
# |    fps             | 781      |
# |    iterations      | 500      |
# |    time_elapsed    | 51       |
# |    total_timesteps | 40000    |
# ---------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 730      |
# |    ep_rew_mean        | 1.27     |
# | time/                 |          |
# |    fps                | 800      |
# |    iterations         | 600      |
# |    time_elapsed       | 59       |
# |    total_timesteps    | 48000    |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | -0.212   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | -0.00916 |
# |    value_loss         | 0.000538 |
# ------------------------------------
# Eval num_timesteps=50000, episode_reward=1.00 +/- 0.89
# Episode length: 709.60 +/- 167.63
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 710      |
# |    mean_reward        | 1        |
# | time/                 |          |
# |    total_timesteps    | 50000    |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | -0.0214  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 624      |
# |    policy_loss        | -0.0245  |
# |    value_loss         | 0.00151  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 706      |
# |    ep_rew_mean        | 1.16     |
# | time/                 |          |
# |    fps                | 803      |
# |    iterations         | 700      |
# |    time_elapsed       | 69       |
# |    total_timesteps    | 56000    |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | 0.0286   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 0.0104   |
# |    value_loss         | 0.0251   |
# ------------------------------------
# Eval num_timesteps=60000, episode_reward=1.40 +/- 1.85
# Episode length: 743.00 +/- 325.44
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 743      |
# |    mean_reward        | 1.4      |
# | time/                 |          |
# |    total_timesteps    | 60000    |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | -0.103   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 749      |
# |    policy_loss        | -0.0723  |
# |    value_loss         | 0.0139   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 712      |
# |    ep_rew_mean        | 1.2      |
# | time/                 |          |
# |    fps                | 801      |
# |    iterations         | 800      |
# |    time_elapsed       | 79       |
# |    total_timesteps    | 64000    |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | -4.25    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | -0.00931 |
# |    value_loss         | 0.000402 |
# ------------------------------------
# Eval num_timesteps=70000, episode_reward=2.00 +/- 2.10
# Episode length: 881.00 +/- 383.51
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 881      |
# |    mean_reward        | 2        |
# | time/                 |          |
# |    total_timesteps    | 70000    |
# | train/                |          |
# |    entropy_loss       | -1.37    |
# |    explained_variance | -0.0269  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 874      |
# |    policy_loss        | -0.0629  |
# |    value_loss         | 0.0118   |
# ------------------------------------
# New best mean reward!
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 751      |
# |    ep_rew_mean        | 1.43     |
# | time/                 |          |
# |    fps                | 797      |
# |    iterations         | 900      |
# |    time_elapsed       | 90       |
# |    total_timesteps    | 72000    |
# | train/                |          |
# |    entropy_loss       | -1.37    |
# |    explained_variance | -0.544   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | -0.0263  |
# |    value_loss         | 0.00141  |
# ------------------------------------
# Eval num_timesteps=80000, episode_reward=1.20 +/- 1.47
# Episode length: 708.20 +/- 257.81
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 708      |
# |    mean_reward        | 1.2      |
# | time/                 |          |
# |    total_timesteps    | 80000    |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | -0.00503 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | -0.082   |
# |    value_loss         | 0.0236   |
# ------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 752      |
# |    ep_rew_mean     | 1.48     |
# | time/              |          |
# |    fps             | 802      |
# |    iterations      | 1000     |
# |    time_elapsed    | 99       |
# |    total_timesteps | 80000    |
# ---------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 713      |
# |    ep_rew_mean        | 1.21     |
# | time/                 |          |
# |    fps                | 816      |
# |    iterations         | 1100     |
# |    time_elapsed       | 107      |
# |    total_timesteps    | 88000    |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | 0.276    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | -0.0317  |
# |    value_loss         | 0.00155  |
# ------------------------------------
# Eval num_timesteps=90000, episode_reward=1.80 +/- 1.47
# Episode length: 820.80 +/- 261.26
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 821      |
# |    mean_reward        | 1.8      |
# | time/                 |          |
# |    total_timesteps    | 90000    |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | 0.0563   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1124     |
# |    policy_loss        | -0.0335  |
# |    value_loss         | 0.00601  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 719      |
# |    ep_rew_mean        | 1.22     |
# | time/                 |          |
# |    fps                | 817      |
# |    iterations         | 1200     |
# |    time_elapsed       | 117      |
# |    total_timesteps    | 96000    |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | 0.0151   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 0.0158   |
# |    value_loss         | 0.0392   |
# ------------------------------------
# Eval num_timesteps=100000, episode_reward=0.20 +/- 0.40
# Episode length: 560.40 +/- 79.05
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 560      |
# |    mean_reward        | 0.2      |
# | time/                 |          |
# |    total_timesteps    | 100000   |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | -0.11    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1249     |
# |    policy_loss        | -0.0963  |
# |    value_loss         | 0.0282   |
# ------------------------------------
# Saving to /home/sequenzia/dev/rl-project/trained-agents/a2c/BreakoutNoFrameskip-v4_1
# wandb: WARNING No program path found, not creating job artifact. See https://docs.wandb.ai/guides/launch/create-job
# wandb:
# wandb: Run history:
# wandb:      eval/mean_ep_length ▄▆▅▃▄▅█▄▇▁
# wandb:         eval/mean_reward ▅▇▅▄▄▆█▅▇▁
# wandb:              global_step ▁▁▂▂▂▃▃▃▄▄▅▅▅▆▆▆▇▇██
# wandb:      rollout/ep_len_mean ▁▅█▇▆▅▃▃▇▇▃▄
# wandb:      rollout/ep_rew_mean ▁▅█▇▆▄▂▃▆▇▃▃
# wandb:                 time/fps ▁▂▄▅▅▇▇▇▆▇██
# wandb:          time/iterations ▁▂▂▃▄▄▅▅▆▇▇█
# wandb:        time/time_elapsed ▁▂▂▃▄▄▅▆▆▇▇█
# wandb:     time/total_timesteps ▁▁▂▂▂▃▃▃▄▄▅▅▅▆▆▆▇▇██
# wandb:       train/entropy_loss ▁▁▁▁▁▁▁▁▂▂▃▂▅▇█▂▃▃▃▆
# wandb: train/explained_variance ████████▇██▇▁█▇████▇
# wandb:      train/learning_rate ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:          train/n_updates ▁▁▂▂▂▃▃▃▄▄▅▅▅▆▆▆▇▇██
# wandb:        train/policy_loss █▇▆▄▇▇▅▃▄▄▅▂▄▂▄▂▃▃▅▁
# wandb:         train/value_loss █▆▃▂▅█▄▃▁▁▃▂▁▂▁▃▁▂▅▄
# wandb:
# wandb: Run summary:
# wandb:      eval/mean_ep_length 560.40002
# wandb:         eval/mean_reward 0.2
# wandb:              global_step 100000
# wandb:      rollout/ep_len_mean 719.34003
# wandb:      rollout/ep_rew_mean 1.22
# wandb:                 time/fps 817.0
# wandb:          time/iterations 1200.0
# wandb:        time/time_elapsed 117.0
# wandb:     time/total_timesteps 100000.0
# wandb:       train/entropy_loss -1.37609
# wandb: train/explained_variance -0.11012
# wandb:      train/learning_rate 0.0007
# wandb:          train/n_updates 1249.0
# wandb:        train/policy_loss -0.09631
# wandb:         train/value_loss 0.02817
# wandb:
# wandb: 🚀 View run BreakoutNoFrameskip-v4__a2c__43__1702876472 at: https://wandb.ai/appliedtheta/Solen-RL-Project/runs/6ww7za2q
# wandb: Synced 7 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# wandb: Find logs at: ./logs/wandb/run-20231218_001433-6ww7za2q/logs
# Exception in thread NetStatThr:
# Traceback (most recent call last):
#   File "/home/sequenzia/anaconda3/envs/gym/lib/python3.9/threading.py", line 950, in _bootstrap_inner
#     self.run()
# Exception in thread   File "/home/sequenzia/anaconda3/envs/gym/lib/python3.9/threading.py", line 888, in run
# ChkStopThr:
# Traceback (most recent call last):
#       File "/home/sequenzia/anaconda3/envs/gym/lib/python3.9/threading.py", line 950, in _bootstrap_inner
# self._target(*self._args, **self._kwargs)
#   File "/home/sequenzia/anaconda3/envs/gym/lib/python3.9/site-packages/wandb/sdk/wandb_run.py", line 268, in check_network_status
#         self._loop_check_status(self.run()
#
#   File "/home/sequenzia/anaconda3/envs/gym/lib/python3.9/site-packages/wandb/sdk/wandb_run.py", line 224, in _loop_check_status
#   File "/home/sequenzia/anaconda3/envs/gym/lib/python3.9/threading.py", line 888, in run
#         local_handle = request()self._target(*self._args, **self._kwargs)
#
#   File "/home/sequenzia/anaconda3/envs/gym/lib/python3.9/site-packages/wandb/sdk/interface/interface.py", line 756, in deliver_network_status
#   File "/home/sequenzia/anaconda3/envs/gym/lib/python3.9/site-packages/wandb/sdk/wandb_run.py", line 286, in check_stop_status
#     return self._deliver_network_status(status)
#       File "/home/sequenzia/anaconda3/envs/gym/lib/python3.9/site-packages/wandb/sdk/interface/interface_shared.py", line 484, in _deliver_network_status
# self._loop_check_status(
#   File "/home/sequenzia/anaconda3/envs/gym/lib/python3.9/site-packages/wandb/sdk/wandb_run.py", line 224, in _loop_check_status
#     return self._deliver_record(record)
# local_handle = request()  File "/home/sequenzia/anaconda3/envs/gym/lib/python3.9/site-packages/wandb/sdk/interface/interface_shared.py", line 437, in _deliver_record
#
#   File "/home/sequenzia/anaconda3/envs/gym/lib/python3.9/site-packages/wandb/sdk/interface/interface.py", line 748, in deliver_stop_status
#     handle = mailbox._deliver_record(record, interface=self)
#   File "/home/sequenzia/anaconda3/envs/gym/lib/python3.9/site-packages/wandb/sdk/lib/mailbox.py", line 455, in _deliver_record
#     return self._deliver_stop_status(status)
#   File "/home/sequenzia/anaconda3/envs/gym/lib/python3.9/site-packages/wandb/sdk/interface/interface_shared.py", line 468, in _deliver_stop_status
#     interface._publish(record)
#   File "/home/sequenzia/anaconda3/envs/gym/lib/python3.9/site-packages/wandb/sdk/interface/interface_sock.py", line 51, in _publish
#     return self._deliver_record(record)
#       File "/home/sequenzia/anaconda3/envs/gym/lib/python3.9/site-packages/wandb/sdk/interface/interface_shared.py", line 437, in _deliver_record
# self._sock_client.send_record_publish(record)
#   File "/home/sequenzia/anaconda3/envs/gym/lib/python3.9/site-packages/wandb/sdk/lib/sock_client.py", line 221, in send_record_publish
#     handle = mailbox._deliver_record(record, interface=self)
# self.send_server_request(server_req)  File "/home/sequenzia/anaconda3/envs/gym/lib/python3.9/site-packages/wandb/sdk/lib/mailbox.py", line 455, in _deliver_record
#
#   File "/home/sequenzia/anaconda3/envs/gym/lib/python3.9/site-packages/wandb/sdk/lib/sock_client.py", line 155, in send_server_request
#     interface._publish(record)
# self._send_message(msg)
#   File "/home/sequenzia/anaconda3/envs/gym/lib/python3.9/site-packages/wandb/sdk/interface/interface_sock.py", line 51, in _publish
#   File "/home/sequenzia/anaconda3/envs/gym/lib/python3.9/site-packages/wandb/sdk/lib/sock_client.py", line 152, in _send_message
#     self._sock_client.send_record_publish(record)
# self._sendall_with_error_handle(header + data)
#   File "/home/sequenzia/anaconda3/envs/gym/lib/python3.9/site-packages/wandb/sdk/lib/sock_client.py", line 221, in send_record_publish
#   File "/home/sequenzia/anaconda3/envs/gym/lib/python3.9/site-packages/wandb/sdk/lib/sock_client.py", line 130, in _sendall_with_error_handle
#     self.send_server_request(server_req)
# sent = self._sock.send(data)  File "/home/sequenzia/anaconda3/envs/gym/lib/python3.9/site-packages/wandb/sdk/lib/sock_client.py", line 155, in send_server_request
#
# BrokenPipeError: [Errno 32] Broken pipe
#     self._send_message(msg)
#   File "/home/sequenzia/anaconda3/envs/gym/lib/python3.9/site-packages/wandb/sdk/lib/sock_client.py", line 152, in _send_message
#     self._sendall_with_error_handle(header + data)
#   File "/home/sequenzia/anaconda3/envs/gym/lib/python3.9/site-packages/wandb/sdk/lib/sock_client.py", line 130, in _sendall_with_error_handle
#     sent = self._sock.send(data)
# BrokenPipeError: [Errno 32] Broken pipe

# %%
ALGO = "ppo"
TAGS = f"{ROM} {ALGO.upper()}"
CONFIG_PATH = f"{CONFIG_DIR}/{ALGO}.yml"
CMD = f"{CMD} --algo {ALGO} --conf {CONFIG_PATH} -tags {TAGS}"

# !{CMD}
# Out:
# ========== BreakoutNoFrameskip-v4 ==========
# Seed: 43
# wandb: Currently logged in as: appliedtheta. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.1
# wandb: Run data is saved locally in /home/sequenzia/dev/rl-project/logs/wandb/run-20231218_001659-57n0lh6y
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run BreakoutNoFrameskip-v4__ppo__43__1702876618
# wandb: ⭐️ View project at https://wandb.ai/appliedtheta/Solen-RL-Project
# wandb: 🚀 View run at https://wandb.ai/appliedtheta/Solen-RL-Project/runs/57n0lh6y
# Loading hyperparameters from: /home/sequenzia/dev/rl-project/configs/ppo.yml
# Default hyperparameters for environment (ones being tuned will be overridden):
# OrderedDict([('batch_size', 256),
#              ('clip_range', 'lin_0.1'),
#              ('ent_coef', 0.01),
#              ('env_wrapper',
#               ['stable_baselines3.common.atari_wrappers.AtariWrapper']),
#              ('frame_stack', 4),
#              ('learning_rate', 'lin_2.5e-4'),
#              ('n_envs', 16),
#              ('n_epochs', 5),
#              ('n_steps', 128),
#              ('n_timesteps', 100000.0),
#              ('policy', 'CnnPolicy'),
#              ('vf_coef', 0.5)])
# Using 16 environments
# Creating test environment
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Using cuda device
# Log path: /home/sequenzia/dev/rl-project/trained-agents/ppo/BreakoutNoFrameskip-v4_1
# Logging to runs/BreakoutNoFrameskip-v4__ppo__43__1702876618/BreakoutNoFrameskip-v4/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 516      |
# |    ep_rew_mean     | 0        |
# | time/              |          |
# |    fps             | 482      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 614          |
# |    ep_rew_mean          | 0.611        |
# | time/                   |              |
# |    fps                  | 595          |
# |    iterations           | 2            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0011265269 |
# |    clip_fraction        | 0.00127      |
# |    clip_range           | 0.098        |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | -0.0462      |
# |    learning_rate        | 0.000245     |
# |    loss                 | 0.00834      |
# |    n_updates            | 5            |
# |    policy_gradient_loss | -0.000264    |
# |    value_loss           | 0.083        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 692           |
# |    ep_rew_mean          | 1             |
# | time/                   |               |
# |    fps                  | 644           |
# |    iterations           | 3             |
# |    time_elapsed         | 9             |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.00092043093 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.0959        |
# |    entropy_loss         | -1.39         |
# |    explained_variance   | 0.032         |
# |    learning_rate        | 0.00024       |
# |    loss                 | 0.0166        |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.000325     |
# |    value_loss           | 0.0734        |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 714          |
# |    ep_rew_mean          | 1.17         |
# | time/                   |              |
# |    fps                  | 684          |
# |    iterations           | 4            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0017818369 |
# |    clip_fraction        | 0.0129       |
# |    clip_range           | 0.0939       |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.111        |
# |    learning_rate        | 0.000235     |
# |    loss                 | 0.0143       |
# |    n_updates            | 15           |
# |    policy_gradient_loss | -0.000828    |
# |    value_loss           | 0.0695       |
# ------------------------------------------
# Eval num_timesteps=10000, episode_reward=2.20 +/- 2.86
# Episode length: 913.00 +/- 502.52
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 913          |
# |    mean_reward          | 2.2          |
# | time/                   |              |
# |    total_timesteps      | 10000        |
# | train/                  |              |
# |    approx_kl            | 0.0025947546 |
# |    clip_fraction        | 0.025        |
# |    clip_range           | 0.0918       |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.287        |
# |    learning_rate        | 0.00023      |
# |    loss                 | 0.00585      |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00132     |
# |    value_loss           | 0.048        |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 703      |
# |    ep_rew_mean     | 1.11     |
# | time/              |          |
# |    fps             | 620      |
# |    iterations      | 5        |
# |    time_elapsed    | 16       |
# |    total_timesteps | 10240    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 693          |
# |    ep_rew_mean          | 1.06         |
# | time/                   |              |
# |    fps                  | 645          |
# |    iterations           | 6            |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0011547572 |
# |    clip_fraction        | 0.0145       |
# |    clip_range           | 0.0898       |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.536        |
# |    learning_rate        | 0.000224     |
# |    loss                 | -0.00582     |
# |    n_updates            | 25           |
# |    policy_gradient_loss | -0.000184    |
# |    value_loss           | 0.0414       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 726          |
# |    ep_rew_mean          | 1.25         |
# | time/                   |              |
# |    fps                  | 663          |
# |    iterations           | 7            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0014682447 |
# |    clip_fraction        | 0.0367       |
# |    clip_range           | 0.0877       |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.659        |
# |    learning_rate        | 0.000219     |
# |    loss                 | -0.00125     |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00173     |
# |    value_loss           | 0.0506       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 728          |
# |    ep_rew_mean          | 1.26         |
# | time/                   |              |
# |    fps                  | 678          |
# |    iterations           | 8            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0019776083 |
# |    clip_fraction        | 0.0345       |
# |    clip_range           | 0.0857       |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.704        |
# |    learning_rate        | 0.000214     |
# |    loss                 | 0.0119       |
# |    n_updates            | 35           |
# |    policy_gradient_loss | -0.000822    |
# |    value_loss           | 0.0481       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 743          |
# |    ep_rew_mean          | 1.38         |
# | time/                   |              |
# |    fps                  | 694          |
# |    iterations           | 9            |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0018982892 |
# |    clip_fraction        | 0.0968       |
# |    clip_range           | 0.0836       |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.751        |
# |    learning_rate        | 0.000209     |
# |    loss                 | -0.00686     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00212     |
# |    value_loss           | 0.0376       |
# ------------------------------------------
# Eval num_timesteps=20000, episode_reward=2.40 +/- 3.38
# Episode length: 822.00 +/- 421.73
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 822          |
# |    mean_reward          | 2.4          |
# | time/                   |              |
# |    total_timesteps      | 20000        |
# | train/                  |              |
# |    approx_kl            | 0.0021664547 |
# |    clip_fraction        | 0.0912       |
# |    clip_range           | 0.0816       |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.825        |
# |    learning_rate        | 0.000204     |
# |    loss                 | 0.00453      |
# |    n_updates            | 45           |
# |    policy_gradient_loss | -0.00273     |
# |    value_loss           | 0.0362       |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 770      |
# |    ep_rew_mean     | 1.54     |
# | time/              |          |
# |    fps             | 664      |
# |    iterations      | 10       |
# |    time_elapsed    | 30       |
# |    total_timesteps | 20480    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 761          |
# |    ep_rew_mean          | 1.5          |
# | time/                   |              |
# |    fps                  | 675          |
# |    iterations           | 11           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0011151172 |
# |    clip_fraction        | 0.0256       |
# |    clip_range           | 0.0795       |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.846        |
# |    learning_rate        | 0.000199     |
# |    loss                 | -0.000947    |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00124     |
# |    value_loss           | 0.0296       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 746         |
# |    ep_rew_mean          | 1.4         |
# | time/                   |             |
# |    fps                  | 686         |
# |    iterations           | 12          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.000755185 |
# |    clip_fraction        | 0.0515      |
# |    clip_range           | 0.0775      |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.907       |
# |    learning_rate        | 0.000194    |
# |    loss                 | -0.00834    |
# |    n_updates            | 55          |
# |    policy_gradient_loss | -0.00052    |
# |    value_loss           | 0.0165      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 740          |
# |    ep_rew_mean          | 1.36         |
# | time/                   |              |
# |    fps                  | 697          |
# |    iterations           | 13           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0009968337 |
# |    clip_fraction        | 0.0399       |
# |    clip_range           | 0.0754       |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.908        |
# |    learning_rate        | 0.000189     |
# |    loss                 | -0.00759     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.000425    |
# |    value_loss           | 0.02         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 771          |
# |    ep_rew_mean          | 1.54         |
# | time/                   |              |
# |    fps                  | 706          |
# |    iterations           | 14           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0012158931 |
# |    clip_fraction        | 0.081        |
# |    clip_range           | 0.0734       |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.937        |
# |    learning_rate        | 0.000183     |
# |    loss                 | -0.00485     |
# |    n_updates            | 65           |
# |    policy_gradient_loss | -0.0017      |
# |    value_loss           | 0.0128       |
# ------------------------------------------
# Eval num_timesteps=30000, episode_reward=1.20 +/- 1.60
# Episode length: 726.40 +/- 276.28
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 726          |
# |    mean_reward          | 1.2          |
# | time/                   |              |
# |    total_timesteps      | 30000        |
# | train/                  |              |
# |    approx_kl            | 0.0009877777 |
# |    clip_fraction        | 0.0809       |
# |    clip_range           | 0.0713       |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.904        |
# |    learning_rate        | 0.000178     |
# |    loss                 | -0.00606     |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00214     |
# |    value_loss           | 0.0212       |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 784      |
# |    ep_rew_mean     | 1.63     |
# | time/              |          |
# |    fps             | 691      |
# |    iterations      | 15       |
# |    time_elapsed    | 44       |
# |    total_timesteps | 30720    |
# ---------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 781           |
# |    ep_rew_mean          | 1.69          |
# | time/                   |               |
# |    fps                  | 697           |
# |    iterations           | 16            |
# |    time_elapsed         | 46            |
# |    total_timesteps      | 32768         |
# | train/                  |               |
# |    approx_kl            | 0.00023664528 |
# |    clip_fraction        | 0.013         |
# |    clip_range           | 0.0693        |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | 0.864         |
# |    learning_rate        | 0.000173      |
# |    loss                 | -0.00305      |
# |    n_updates            | 75            |
# |    policy_gradient_loss | -0.000322     |
# |    value_loss           | 0.0265        |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 798          |
# |    ep_rew_mean          | 1.82         |
# | time/                   |              |
# |    fps                  | 704          |
# |    iterations           | 17           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0013421639 |
# |    clip_fraction        | 0.0571       |
# |    clip_range           | 0.0672       |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.847        |
# |    learning_rate        | 0.000168     |
# |    loss                 | -0.0105      |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00104     |
# |    value_loss           | 0.0257       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 776          |
# |    ep_rew_mean          | 1.69         |
# | time/                   |              |
# |    fps                  | 709          |
# |    iterations           | 18           |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0014917047 |
# |    clip_fraction        | 0.122        |
# |    clip_range           | 0.0652       |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.92         |
# |    learning_rate        | 0.000163     |
# |    loss                 | -0.0106      |
# |    n_updates            | 85           |
# |    policy_gradient_loss | -0.00309     |
# |    value_loss           | 0.0153       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 793          |
# |    ep_rew_mean          | 1.81         |
# | time/                   |              |
# |    fps                  | 716          |
# |    iterations           | 19           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0009964561 |
# |    clip_fraction        | 0.0745       |
# |    clip_range           | 0.0631       |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.86         |
# |    learning_rate        | 0.000158     |
# |    loss                 | -0.0123      |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00158     |
# |    value_loss           | 0.0244       |
# ------------------------------------------
# Eval num_timesteps=40000, episode_reward=3.00 +/- 4.10
# Episode length: 926.00 +/- 518.06
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 926          |
# |    mean_reward          | 3            |
# | time/                   |              |
# |    total_timesteps      | 40000        |
# | train/                  |              |
# |    approx_kl            | 0.0004668603 |
# |    clip_fraction        | 0.0189       |
# |    clip_range           | 0.0611       |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.865        |
# |    learning_rate        | 0.000153     |
# |    loss                 | -0.00363     |
# |    n_updates            | 95           |
# |    policy_gradient_loss | -0.000632    |
# |    value_loss           | 0.0272       |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 820      |
# |    ep_rew_mean     | 2.01     |
# | time/              |          |
# |    fps             | 696      |
# |    iterations      | 20       |
# |    time_elapsed    | 58       |
# |    total_timesteps | 40960    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 832          |
# |    ep_rew_mean          | 2.12         |
# | time/                   |              |
# |    fps                  | 701          |
# |    iterations           | 21           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0009852548 |
# |    clip_fraction        | 0.107        |
# |    clip_range           | 0.059        |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.885        |
# |    learning_rate        | 0.000148     |
# |    loss                 | -0.0061      |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00196     |
# |    value_loss           | 0.0193       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 826           |
# |    ep_rew_mean          | 2.09          |
# | time/                   |               |
# |    fps                  | 704           |
# |    iterations           | 22            |
# |    time_elapsed         | 63            |
# |    total_timesteps      | 45056         |
# | train/                  |               |
# |    approx_kl            | 0.00074572104 |
# |    clip_fraction        | 0.0678        |
# |    clip_range           | 0.057         |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | 0.897         |
# |    learning_rate        | 0.000142      |
# |    loss                 | -0.00632      |
# |    n_updates            | 105           |
# |    policy_gradient_loss | -0.00151      |
# |    value_loss           | 0.0197        |
# -------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 849        |
# |    ep_rew_mean          | 2.22       |
# | time/                   |            |
# |    fps                  | 708        |
# |    iterations           | 23         |
# |    time_elapsed         | 66         |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.00083968 |
# |    clip_fraction        | 0.0707     |
# |    clip_range           | 0.0549     |
# |    entropy_loss         | -1.37      |
# |    explained_variance   | 0.931      |
# |    learning_rate        | 0.000137   |
# |    loss                 | -0.0106    |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.00153   |
# |    value_loss           | 0.0143     |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 862          |
# |    ep_rew_mean          | 2.31         |
# | time/                   |              |
# |    fps                  | 711          |
# |    iterations           | 24           |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0005285003 |
# |    clip_fraction        | 0.0691       |
# |    clip_range           | 0.0529       |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.838        |
# |    learning_rate        | 0.000132     |
# |    loss                 | -0.00783     |
# |    n_updates            | 115          |
# |    policy_gradient_loss | -0.00112     |
# |    value_loss           | 0.0286       |
# ------------------------------------------
# Eval num_timesteps=50000, episode_reward=1.60 +/- 1.50
# Episode length: 776.60 +/- 247.76
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 777          |
# |    mean_reward          | 1.6          |
# | time/                   |              |
# |    total_timesteps      | 50000        |
# | train/                  |              |
# |    approx_kl            | 0.0004122147 |
# |    clip_fraction        | 0.0235       |
# |    clip_range           | 0.0508       |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.946        |
# |    learning_rate        | 0.000127     |
# |    loss                 | -0.0123      |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00103     |
# |    value_loss           | 0.00927      |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 842      |
# |    ep_rew_mean     | 2.14     |
# | time/              |          |
# |    fps             | 696      |
# |    iterations      | 25       |
# |    time_elapsed    | 73       |
# |    total_timesteps | 51200    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 817          |
# |    ep_rew_mean          | 1.95         |
# | time/                   |              |
# |    fps                  | 701          |
# |    iterations           | 26           |
# |    time_elapsed         | 75           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0007062426 |
# |    clip_fraction        | 0.0558       |
# |    clip_range           | 0.0488       |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.877        |
# |    learning_rate        | 0.000122     |
# |    loss                 | -0.00732     |
# |    n_updates            | 125          |
# |    policy_gradient_loss | -0.00141     |
# |    value_loss           | 0.022        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 838          |
# |    ep_rew_mean          | 2.06         |
# | time/                   |              |
# |    fps                  | 706          |
# |    iterations           | 27           |
# |    time_elapsed         | 78           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0006378853 |
# |    clip_fraction        | 0.0798       |
# |    clip_range           | 0.0468       |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.894        |
# |    learning_rate        | 0.000117     |
# |    loss                 | -0.0039      |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00227     |
# |    value_loss           | 0.0251       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 838           |
# |    ep_rew_mean          | 2.05          |
# | time/                   |               |
# |    fps                  | 710           |
# |    iterations           | 28            |
# |    time_elapsed         | 80            |
# |    total_timesteps      | 57344         |
# | train/                  |               |
# |    approx_kl            | 0.00050817814 |
# |    clip_fraction        | 0.0801        |
# |    clip_range           | 0.0447        |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | 0.807         |
# |    learning_rate        | 0.000112      |
# |    loss                 | 0.000983      |
# |    n_updates            | 135           |
# |    policy_gradient_loss | -0.00144      |
# |    value_loss           | 0.0318        |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 848           |
# |    ep_rew_mean          | 2.14          |
# | time/                   |               |
# |    fps                  | 714           |
# |    iterations           | 29            |
# |    time_elapsed         | 83            |
# |    total_timesteps      | 59392         |
# | train/                  |               |
# |    approx_kl            | 0.00033183533 |
# |    clip_fraction        | 0.0868        |
# |    clip_range           | 0.0427        |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | 0.859         |
# |    learning_rate        | 0.000107      |
# |    loss                 | -0.00513      |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.00144      |
# |    value_loss           | 0.0295        |
# -------------------------------------------
# Eval num_timesteps=60000, episode_reward=1.20 +/- 1.94
# Episode length: 741.60 +/- 336.21
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 742           |
# |    mean_reward          | 1.2           |
# | time/                   |               |
# |    total_timesteps      | 60000         |
# | train/                  |               |
# |    approx_kl            | 0.00037582024 |
# |    clip_fraction        | 0.0972        |
# |    clip_range           | 0.0406        |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | 0.928         |
# |    learning_rate        | 0.000102      |
# |    loss                 | -0.01         |
# |    n_updates            | 145           |
# |    policy_gradient_loss | -0.00181      |
# |    value_loss           | 0.0163        |
# -------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 841      |
# |    ep_rew_mean     | 2.09     |
# | time/              |          |
# |    fps             | 703      |
# |    iterations      | 30       |
# |    time_elapsed    | 87       |
# |    total_timesteps | 61440    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 863          |
# |    ep_rew_mean          | 2.23         |
# | time/                   |              |
# |    fps                  | 704          |
# |    iterations           | 31           |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0003968647 |
# |    clip_fraction        | 0.115        |
# |    clip_range           | 0.0386       |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.811        |
# |    learning_rate        | 9.64e-05     |
# |    loss                 | -0.000461    |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.000921    |
# |    value_loss           | 0.0355       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 838           |
# |    ep_rew_mean          | 2.09          |
# | time/                   |               |
# |    fps                  | 706           |
# |    iterations           | 32            |
# |    time_elapsed         | 92            |
# |    total_timesteps      | 65536         |
# | train/                  |               |
# |    approx_kl            | 0.00027452767 |
# |    clip_fraction        | 0.124         |
# |    clip_range           | 0.0365        |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | 0.879         |
# |    learning_rate        | 9.13e-05      |
# |    loss                 | -0.00864      |
# |    n_updates            | 155           |
# |    policy_gradient_loss | -0.00168      |
# |    value_loss           | 0.0212        |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 835          |
# |    ep_rew_mean          | 2.06         |
# | time/                   |              |
# |    fps                  | 709          |
# |    iterations           | 33           |
# |    time_elapsed         | 95           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0002965703 |
# |    clip_fraction        | 0.0653       |
# |    clip_range           | 0.0345       |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.849        |
# |    learning_rate        | 8.62e-05     |
# |    loss                 | -0.00386     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00135     |
# |    value_loss           | 0.0293       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 833           |
# |    ep_rew_mean          | 2.03          |
# | time/                   |               |
# |    fps                  | 712           |
# |    iterations           | 34            |
# |    time_elapsed         | 97            |
# |    total_timesteps      | 69632         |
# | train/                  |               |
# |    approx_kl            | 0.00021433758 |
# |    clip_fraction        | 0.0756        |
# |    clip_range           | 0.0324        |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | 0.918         |
# |    learning_rate        | 8.1e-05       |
# |    loss                 | -0.0061       |
# |    n_updates            | 165           |
# |    policy_gradient_loss | -0.00136      |
# |    value_loss           | 0.0193        |
# -------------------------------------------
# Eval num_timesteps=70000, episode_reward=3.60 +/- 3.14
# Episode length: 1021.60 +/- 418.22
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1.02e+03      |
# |    mean_reward          | 3.6           |
# | time/                   |               |
# |    total_timesteps      | 70000         |
# | train/                  |               |
# |    approx_kl            | 0.00017821317 |
# |    clip_fraction        | 0.0875        |
# |    clip_range           | 0.0304        |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | 0.865         |
# |    learning_rate        | 7.59e-05      |
# |    loss                 | -0.0073       |
# |    n_updates            | 170           |
# |    policy_gradient_loss | -0.00111      |
# |    value_loss           | 0.0264        |
# -------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 849      |
# |    ep_rew_mean     | 2.16     |
# | time/              |          |
# |    fps             | 698      |
# |    iterations      | 35       |
# |    time_elapsed    | 102      |
# |    total_timesteps | 71680    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 866          |
# |    ep_rew_mean          | 2.26         |
# | time/                   |              |
# |    fps                  | 701          |
# |    iterations           | 36           |
# |    time_elapsed         | 105          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0002332193 |
# |    clip_fraction        | 0.0938       |
# |    clip_range           | 0.0283       |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.871        |
# |    learning_rate        | 7.08e-05     |
# |    loss                 | -0.00592     |
# |    n_updates            | 175          |
# |    policy_gradient_loss | -0.00131     |
# |    value_loss           | 0.0264       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 873           |
# |    ep_rew_mean          | 2.32          |
# | time/                   |               |
# |    fps                  | 704           |
# |    iterations           | 37            |
# |    time_elapsed         | 107           |
# |    total_timesteps      | 75776         |
# | train/                  |               |
# |    approx_kl            | 0.00013544437 |
# |    clip_fraction        | 0.0798        |
# |    clip_range           | 0.0263        |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | 0.842         |
# |    learning_rate        | 6.57e-05      |
# |    loss                 | -0.00296      |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.00121      |
# |    value_loss           | 0.0276        |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 866          |
# |    ep_rew_mean          | 2.26         |
# | time/                   |              |
# |    fps                  | 707          |
# |    iterations           | 38           |
# |    time_elapsed         | 110          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0001233198 |
# |    clip_fraction        | 0.121        |
# |    clip_range           | 0.0242       |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.778        |
# |    learning_rate        | 6.06e-05     |
# |    loss                 | 0.00351      |
# |    n_updates            | 185          |
# |    policy_gradient_loss | -0.000789    |
# |    value_loss           | 0.0397       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 853           |
# |    ep_rew_mean          | 2.16          |
# | time/                   |               |
# |    fps                  | 709           |
# |    iterations           | 39            |
# |    time_elapsed         | 112           |
# |    total_timesteps      | 79872         |
# | train/                  |               |
# |    approx_kl            | 0.00012431241 |
# |    clip_fraction        | 0.0926        |
# |    clip_range           | 0.0222        |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | 0.808         |
# |    learning_rate        | 5.54e-05      |
# |    loss                 | 0.00324       |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -0.000872     |
# |    value_loss           | 0.0391        |
# -------------------------------------------
# Eval num_timesteps=80000, episode_reward=2.20 +/- 2.48
# Episode length: 886.80 +/- 464.12
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 887          |
# |    mean_reward          | 2.2          |
# | time/                   |              |
# |    total_timesteps      | 80000        |
# | train/                  |              |
# |    approx_kl            | 8.954137e-05 |
# |    clip_fraction        | 0.0987       |
# |    clip_range           | 0.0201       |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.769        |
# |    learning_rate        | 5.03e-05     |
# |    loss                 | 0.00314      |
# |    n_updates            | 195          |
# |    policy_gradient_loss | -0.000707    |
# |    value_loss           | 0.0379       |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 864      |
# |    ep_rew_mean     | 2.21     |
# | time/              |          |
# |    fps             | 700      |
# |    iterations      | 40       |
# |    time_elapsed    | 116      |
# |    total_timesteps | 81920    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 864          |
# |    ep_rew_mean          | 2.22         |
# | time/                   |              |
# |    fps                  | 703          |
# |    iterations           | 41           |
# |    time_elapsed         | 119          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 9.134103e-05 |
# |    clip_fraction        | 0.147        |
# |    clip_range           | 0.0181       |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.768        |
# |    learning_rate        | 4.52e-05     |
# |    loss                 | 0.00478      |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.000375    |
# |    value_loss           | 0.0413       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 872          |
# |    ep_rew_mean          | 2.26         |
# | time/                   |              |
# |    fps                  | 706          |
# |    iterations           | 42           |
# |    time_elapsed         | 121          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 7.050755e-05 |
# |    clip_fraction        | 0.192        |
# |    clip_range           | 0.016        |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.885        |
# |    learning_rate        | 4.01e-05     |
# |    loss                 | -0.00685     |
# |    n_updates            | 205          |
# |    policy_gradient_loss | -0.00103     |
# |    value_loss           | 0.0225       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 870           |
# |    ep_rew_mean          | 2.27          |
# | time/                   |               |
# |    fps                  | 708           |
# |    iterations           | 43            |
# |    time_elapsed         | 124           |
# |    total_timesteps      | 88064         |
# | train/                  |               |
# |    approx_kl            | 3.3657096e-05 |
# |    clip_fraction        | 0.0843        |
# |    clip_range           | 0.014         |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | 0.784         |
# |    learning_rate        | 3.5e-05       |
# |    loss                 | 0.000192      |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -0.000459     |
# |    value_loss           | 0.0387        |
# -------------------------------------------
# Eval num_timesteps=90000, episode_reward=2.60 +/- 2.06
# Episode length: 966.60 +/- 373.76
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 967           |
# |    mean_reward          | 2.6           |
# | time/                   |               |
# |    total_timesteps      | 90000         |
# | train/                  |               |
# |    approx_kl            | 3.1908916e-05 |
# |    clip_fraction        | 0.0931        |
# |    clip_range           | 0.0119        |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | 0.832         |
# |    learning_rate        | 2.98e-05      |
# |    loss                 | -0.00274      |
# |    n_updates            | 215           |
# |    policy_gradient_loss | -0.000484     |
# |    value_loss           | 0.0311        |
# -------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 888      |
# |    ep_rew_mean     | 2.38     |
# | time/              |          |
# |    fps             | 700      |
# |    iterations      | 44       |
# |    time_elapsed    | 128      |
# |    total_timesteps | 90112    |
# ---------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 866           |
# |    ep_rew_mean          | 2.21          |
# | time/                   |               |
# |    fps                  | 703           |
# |    iterations           | 45            |
# |    time_elapsed         | 131           |
# |    total_timesteps      | 92160         |
# | train/                  |               |
# |    approx_kl            | 1.9639061e-05 |
# |    clip_fraction        | 0.0741        |
# |    clip_range           | 0.00989       |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | 0.816         |
# |    learning_rate        | 2.47e-05      |
# |    loss                 | 0.000547      |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -0.000321     |
# |    value_loss           | 0.0351        |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 845           |
# |    ep_rew_mean          | 2.05          |
# | time/                   |               |
# |    fps                  | 706           |
# |    iterations           | 46            |
# |    time_elapsed         | 133           |
# |    total_timesteps      | 94208         |
# | train/                  |               |
# |    approx_kl            | 1.7970335e-05 |
# |    clip_fraction        | 0.098         |
# |    clip_range           | 0.00784       |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | 0.787         |
# |    learning_rate        | 1.96e-05      |
# |    loss                 | 0.00124       |
# |    n_updates            | 225           |
# |    policy_gradient_loss | -0.000303     |
# |    value_loss           | 0.0367        |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 855           |
# |    ep_rew_mean          | 2.15          |
# | time/                   |               |
# |    fps                  | 709           |
# |    iterations           | 47            |
# |    time_elapsed         | 135           |
# |    total_timesteps      | 96256         |
# | train/                  |               |
# |    approx_kl            | 7.3271513e-06 |
# |    clip_fraction        | 0.118         |
# |    clip_range           | 0.00579       |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | 0.832         |
# |    learning_rate        | 1.45e-05      |
# |    loss                 | 0.000617      |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -0.000173     |
# |    value_loss           | 0.0338        |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 878           |
# |    ep_rew_mean          | 2.26          |
# | time/                   |               |
# |    fps                  | 711           |
# |    iterations           | 48            |
# |    time_elapsed         | 138           |
# |    total_timesteps      | 98304         |
# | train/                  |               |
# |    approx_kl            | 7.6133583e-06 |
# |    clip_fraction        | 0.158         |
# |    clip_range           | 0.00374       |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | 0.792         |
# |    learning_rate        | 9.36e-06      |
# |    loss                 | 0.0102        |
# |    n_updates            | 235           |
# |    policy_gradient_loss | -0.000113     |
# |    value_loss           | 0.0406        |
# -------------------------------------------
# Eval num_timesteps=100000, episode_reward=2.60 +/- 1.74
# Episode length: 944.00 +/- 330.69
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 944           |
# |    mean_reward          | 2.6           |
# | time/                   |               |
# |    total_timesteps      | 100000        |
# | train/                  |               |
# |    approx_kl            | 1.6986742e-06 |
# |    clip_fraction        | 0.21          |
# |    clip_range           | 0.0017        |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | 0.869         |
# |    learning_rate        | 4.24e-06      |
# |    loss                 | 0.000336      |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -5.67e-05     |
# |    value_loss           | 0.0282        |
# -------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 864      |
# |    ep_rew_mean     | 2.17     |
# | time/              |          |
# |    fps             | 703      |
# |    iterations      | 49       |
# |    time_elapsed    | 142      |
# |    total_timesteps | 100352   |
# ---------------------------------
# Saving to /home/sequenzia/dev/rl-project/trained-agents/ppo/BreakoutNoFrameskip-v4_1
# wandb: WARNING No program path found, not creating job artifact. See https://docs.wandb.ai/guides/launch/create-job
# wandb:
# wandb: Run history:
# wandb:        eval/mean_ep_length ▅▃▁▆▂▁█▅▇▆
# wandb:           eval/mean_reward ▄▅▁▆▂▁█▄▅▅
# wandb:                global_step ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███
# wandb:        rollout/ep_len_mean ▁▃▄▅▅▅▅▅▆▅▅▆▆▆▆▆▇▇▇█▇▇▇▇▇█▇▇▇██▇█████▇▇█
# wandb:        rollout/ep_rew_mean ▁▃▄▄▄▅▅▅▆▅▅▆▆▆▆▆▇▇██▇▇▇▇▇█▇▇▇██▇▇███▇▇▇▇
# wandb:                   time/fps ▁▄▆▇▅▆▇▇▆▇▇█▇███▇███▇███████▇███████████
# wandb:            time/iterations ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:          time/time_elapsed ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███
# wandb:       time/total_timesteps ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███
# wandb:            train/approx_kl ▄▃▆█▄▆▆▇▄▃▄▄▂▅▅▂▄▃▃▂▃▃▂▂▂▂▂▂▁▂▁▁▁▁▁▁▁▁▁▁
# wandb:        train/clip_fraction ▁▁▁▂▁▂▄▄▂▃▄▄▁▃▅▂▅▃▃▃▃▄▄▄▄▅▃▄▄▄▅▄▄▆▇▄▃▄▅█
# wandb:           train/clip_range ████▇▇▇▇▇▇▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▁▁▁
# wandb:         train/entropy_loss ▁▁▁▂▂▄▄▇████▆▆▅▅▄▄▄▄▃▄▄▄▄▃▃▄▄▅▃▄▃▃▄▄▄▄▄▄
# wandb:   train/explained_variance ▁▂▂▃▅▆▇▇▇███▇▇█▇███▇██▇▇██▇█▇█▇▇▇▇█▇▇▇▇█
# wandb:        train/learning_rate ████▇▇▇▇▇▇▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▁▁▁
# wandb:                 train/loss ▆█▇▅▂▇▂▅▃▂▂▂▃▁▁▃▂▂▁▂▂▃▄▂▁▂▃▂▂▂▅▅▅▅▂▃▄▄▄▄
# wandb:            train/n_updates ▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb: train/policy_gradient_loss █▇▆▅█▆▃▂▅▇▄▃▇▆▁▇▄▅▅▆▅▃▅▅▄▄▅▅▆▅▆▆▇▇▆▇▇▇██
# wandb:           train/value_loss █▇▇▅▄▅▃▃▃▁▁▂▂▂▁▂▂▂▁▃▂▂▃▃▁▂▃▂▂▂▄▄▄▄▂▃▃▃▃▃
# wandb:
# wandb: Run summary:
# wandb:        eval/mean_ep_length 944.0
# wandb:           eval/mean_reward 2.6
# wandb:                global_step 100352
# wandb:        rollout/ep_len_mean 863.82001
# wandb:        rollout/ep_rew_mean 2.17
# wandb:                   time/fps 703.0
# wandb:            time/iterations 49.0
# wandb:          time/time_elapsed 142.0
# wandb:       time/total_timesteps 100352.0
# wandb:            train/approx_kl 0.0
# wandb:        train/clip_fraction 0.21006
# wandb:           train/clip_range 0.0017
# wandb:         train/entropy_loss -1.36838
# wandb:   train/explained_variance 0.86857
# wandb:        train/learning_rate 0.0
# wandb:                 train/loss 0.00034
# wandb:            train/n_updates 240.0
# wandb: train/policy_gradient_loss -6e-05
# wandb:           train/value_loss 0.02821
# wandb:
# wandb: 🚀 View run BreakoutNoFrameskip-v4__ppo__43__1702876618 at: https://wandb.ai/appliedtheta/Solen-RL-Project/runs/57n0lh6y
# wandb: Synced 7 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# wandb: Find logs at: ./logs/wandb/run-20231218_001659-57n0lh6y/logs

# %%
ALGO = "dqn"
TAGS = f"{ROM} {ALGO.upper()}"
CONFIG_PATH = f"{CONFIG_DIR}/{ALGO}.yml"
CMD = f"{CMD} --algo {ALGO} --conf {CONFIG_PATH} -tags {TAGS} --save-replay-buffer"

# !{CMD}
# Out:
# ========== BreakoutNoFrameskip-v4 ==========
# Seed: 43
# wandb: Currently logged in as: appliedtheta. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.1
# wandb: Run data is saved locally in /home/sequenzia/dev/rl-project/logs/wandb/run-20231218_001945-35hmzgtt
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run BreakoutNoFrameskip-v4__dqn__43__1702876785
# wandb: ⭐️ View project at https://wandb.ai/appliedtheta/Solen-RL-Project
# wandb: 🚀 View run at https://wandb.ai/appliedtheta/Solen-RL-Project/runs/35hmzgtt
# Loading hyperparameters from: /home/sequenzia/dev/rl-project/configs/dqn.yml
# Default hyperparameters for environment (ones being tuned will be overridden):
# OrderedDict([('batch_size', 32),
#              ('buffer_size', 100000),
#              ('env_wrapper',
#               ['stable_baselines3.common.atari_wrappers.AtariWrapper']),
#              ('exploration_final_eps', 0.01),
#              ('exploration_fraction', 0.1),
#              ('frame_stack', 4),
#              ('gradient_steps', 1),
#              ('learning_rate', 0.0001),
#              ('learning_starts', 100000),
#              ('n_timesteps', 100000.0),
#              ('optimize_memory_usage', False),
#              ('policy', 'CnnPolicy'),
#              ('target_update_interval', 1000),
#              ('train_freq', 1)])
# Using 1 environments
# Creating test environment
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Using cuda device
# Log path: /home/sequenzia/dev/rl-project/trained-agents/dqn/BreakoutNoFrameskip-v4_1
# Logging to runs/BreakoutNoFrameskip-v4__dqn__43__1702876785/BreakoutNoFrameskip-v4/DQN_1
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 596      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 165      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 810      |
# |    ep_rew_mean      | 2        |
# |    exploration_rate | 0.975    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 674      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 255      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 660      |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.961    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 761      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 391      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 678      |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.952    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 799      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 481      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 636      |
# |    ep_rew_mean      | 0.75     |
# |    exploration_rate | 0.943    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 824      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 571      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 636      |
# |    ep_rew_mean      | 0.75     |
# |    exploration_rate | 0.92     |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 894      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 806      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 729      |
# |    ep_rew_mean      | 1.2      |
# |    exploration_rate | 0.911    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 905      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 896      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 691      |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.902    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 911      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 986      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 695      |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.888    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 912      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1127     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 711      |
# |    ep_rew_mean      | 1.12     |
# |    exploration_rate | 0.872    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 930      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1290     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 711      |
# |    ep_rew_mean      | 1.12     |
# |    exploration_rate | 0.861    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 942      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1408     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 701      |
# |    ep_rew_mean      | 1.11     |
# |    exploration_rate | 0.847    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 951      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1542     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 732      |
# |    ep_rew_mean      | 1.3      |
# |    exploration_rate | 0.828    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 959      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1739     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 740      |
# |    ep_rew_mean      | 1.36     |
# |    exploration_rate | 0.814    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 960      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1877     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 738      |
# |    ep_rew_mean      | 1.33     |
# |    exploration_rate | 0.801    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 960      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2015     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 738      |
# |    ep_rew_mean      | 1.33     |
# |    exploration_rate | 0.789    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 961      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2133     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 730      |
# |    ep_rew_mean      | 1.31     |
# |    exploration_rate | 0.763    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 974      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2397     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 779      |
# |    ep_rew_mean      | 1.57     |
# |    exploration_rate | 0.749    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 976      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2538     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 775      |
# |    ep_rew_mean      | 1.53     |
# |    exploration_rate | 0.735    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 977      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2674     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 760      |
# |    ep_rew_mean      | 1.44     |
# |    exploration_rate | 0.726    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 976      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2766     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 760      |
# |    ep_rew_mean      | 1.44     |
# |    exploration_rate | 0.713    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 980      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2903     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 757      |
# |    ep_rew_mean      | 1.41     |
# |    exploration_rate | 0.689    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 981      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3137     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 775      |
# |    ep_rew_mean      | 1.5      |
# |    exploration_rate | 0.681    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 979      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3227     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 762      |
# |    ep_rew_mean      | 1.42     |
# |    exploration_rate | 0.671    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 979      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3319     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 751      |
# |    ep_rew_mean      | 1.35     |
# |    exploration_rate | 0.662    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 980      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3411     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 751      |
# |    ep_rew_mean      | 1.35     |
# |    exploration_rate | 0.649    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 984      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3547     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 749      |
# |    ep_rew_mean      | 1.33     |
# |    exploration_rate | 0.635    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 986      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3683     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 751      |
# |    ep_rew_mean      | 1.36     |
# |    exploration_rate | 0.619    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 990      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3847     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 757      |
# |    ep_rew_mean      | 1.39     |
# |    exploration_rate | 0.606    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 992      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3983     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 748      |
# |    ep_rew_mean      | 1.33     |
# |    exploration_rate | 0.597    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 991      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4075     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 748      |
# |    ep_rew_mean      | 1.33     |
# |    exploration_rate | 0.588    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 992      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4165     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 739      |
# |    ep_rew_mean      | 1.28     |
# |    exploration_rate | 0.579    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 991      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4257     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 731      |
# |    ep_rew_mean      | 1.23     |
# |    exploration_rate | 0.57     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 992      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4345     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 734      |
# |    ep_rew_mean      | 1.26     |
# |    exploration_rate | 0.553    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 994      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4512     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 726      |
# |    ep_rew_mean      | 1.21     |
# |    exploration_rate | 0.544    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 994      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4602     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 726      |
# |    ep_rew_mean      | 1.21     |
# |    exploration_rate | 0.515    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 976      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 4894     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 747      |
# |    ep_rew_mean      | 1.34     |
# |    exploration_rate | 0.507    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 967      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 4982     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 739      |
# |    ep_rew_mean      | 1.3      |
# |    exploration_rate | 0.495    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 962      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5100     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 742      |
# |    ep_rew_mean      | 1.32     |
# |    exploration_rate | 0.481    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 959      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5238     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 741      |
# |    ep_rew_mean      | 1.31     |
# |    exploration_rate | 0.468    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 944      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5372     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 741      |
# |    ep_rew_mean      | 1.31     |
# |    exploration_rate | 0.439    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 934      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 5665     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 758      |
# |    ep_rew_mean      | 1.42     |
# |    exploration_rate | 0.421    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 934      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 5852     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 780      |
# |    ep_rew_mean      | 1.53     |
# |    exploration_rate | 0.397    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 934      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 6091     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 772      |
# |    ep_rew_mean      | 1.49     |
# |    exploration_rate | 0.388    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 933      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 6183     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 771      |
# |    ep_rew_mean      | 1.47     |
# |    exploration_rate | 0.374    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 932      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 6322     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 771      |
# |    ep_rew_mean      | 1.47     |
# |    exploration_rate | 0.361    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 935      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 6456     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 769      |
# |    ep_rew_mean      | 1.46     |
# |    exploration_rate | 0.352    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 936      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 6546     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 765      |
# |    ep_rew_mean      | 1.45     |
# |    exploration_rate | 0.34     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 936      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 6666     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 762      |
# |    ep_rew_mean      | 1.44     |
# |    exploration_rate | 0.328    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 935      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 6784     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 760      |
# |    ep_rew_mean      | 1.43     |
# |    exploration_rate | 0.315    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 937      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 6917     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 760      |
# |    ep_rew_mean      | 1.43     |
# |    exploration_rate | 0.302    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 939      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 7054     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 759      |
# |    ep_rew_mean      | 1.41     |
# |    exploration_rate | 0.293    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 940      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 7146     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 753      |
# |    ep_rew_mean      | 1.38     |
# |    exploration_rate | 0.276    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 940      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 7313     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 760      |
# |    ep_rew_mean      | 1.42     |
# |    exploration_rate | 0.262    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 942      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 7451     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 757      |
# |    ep_rew_mean      | 1.41     |
# |    exploration_rate | 0.251    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 943      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 7565     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 757      |
# |    ep_rew_mean      | 1.41     |
# |    exploration_rate | 0.237    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 945      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 7705     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 756      |
# |    ep_rew_mean      | 1.4      |
# |    exploration_rate | 0.223    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 946      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 7845     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 755      |
# |    ep_rew_mean      | 1.39     |
# |    exploration_rate | 0.212    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 948      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 7964     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 760      |
# |    ep_rew_mean      | 1.43     |
# |    exploration_rate | 0.193    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 950      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 8149     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 755      |
# |    ep_rew_mean      | 1.4      |
# |    exploration_rate | 0.184    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 951      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 8239     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 755      |
# |    ep_rew_mean      | 1.4      |
# |    exploration_rate | 0.175    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 952      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 8331     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 751      |
# |    ep_rew_mean      | 1.37     |
# |    exploration_rate | 0.157    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 954      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 8515     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 754      |
# |    ep_rew_mean      | 1.38     |
# |    exploration_rate | 0.148    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 955      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 8605     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 755      |
# |    ep_rew_mean      | 1.39     |
# |    exploration_rate | 0.132    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 956      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 8772     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 751      |
# |    ep_rew_mean      | 1.37     |
# |    exploration_rate | 0.122    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 957      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 8864     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 751      |
# |    ep_rew_mean      | 1.37     |
# |    exploration_rate | 0.0991   |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 961      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 9100     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 758      |
# |    ep_rew_mean      | 1.4      |
# |    exploration_rate | 0.0854   |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 962      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 9238     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 757      |
# |    ep_rew_mean      | 1.39     |
# |    exploration_rate | 0.0718   |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 963      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 9376     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 756      |
# |    ep_rew_mean      | 1.38     |
# |    exploration_rate | 0.0629   |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 964      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 9466     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 761      |
# |    ep_rew_mean      | 1.41     |
# |    exploration_rate | 0.042    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 966      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 9677     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 761      |
# |    ep_rew_mean      | 1.41     |
# |    exploration_rate | 0.0329   |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 967      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 9769     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 759      |
# |    ep_rew_mean      | 1.4      |
# |    exploration_rate | 0.0133   |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 969      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 9967     |
# ----------------------------------
# Eval num_timesteps=10000, episode_reward=2.20 +/- 4.40
# Episode length: 639.40 +/- 233.87
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 639      |
# |    mean_reward      | 2.2      |
# | rollout/            |          |
# |    exploration_rate | 0.0101   |
# | time/               |          |
# |    total_timesteps  | 10000    |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 760      |
# |    ep_rew_mean      | 1.41     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 864      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 10055    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 756      |
# |    ep_rew_mean      | 1.39     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 865      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 10145    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 752      |
# |    ep_rew_mean      | 1.37     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 866      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 10235    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 752      |
# |    ep_rew_mean      | 1.37     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 867      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 10327    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 748      |
# |    ep_rew_mean      | 1.34     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 868      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 10417    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 747      |
# |    ep_rew_mean      | 1.34     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 872      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 10648    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 750      |
# |    ep_rew_mean      | 1.35     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 873      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 10740    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 746      |
# |    ep_rew_mean      | 1.33     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 874      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 10828    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 746      |
# |    ep_rew_mean      | 1.33     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 876      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 10969    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 745      |
# |    ep_rew_mean      | 1.32     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 879      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 11156    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 752      |
# |    ep_rew_mean      | 1.36     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 881      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 11319    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 749      |
# |    ep_rew_mean      | 1.34     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 883      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 11484    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 766      |
# |    ep_rew_mean      | 1.49     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 888      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 11852    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 766      |
# |    ep_rew_mean      | 1.49     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 889      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 11944    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 763      |
# |    ep_rew_mean      | 1.46     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 890      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 12108    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 763      |
# |    ep_rew_mean      | 1.47     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 891      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 12272    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 764      |
# |    ep_rew_mean      | 1.48     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 891      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 12362    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 763      |
# |    ep_rew_mean      | 1.47     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 892      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 12500    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 763      |
# |    ep_rew_mean      | 1.47     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 894      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 12638    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 763      |
# |    ep_rew_mean      | 1.47     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 895      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 12730    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 760      |
# |    ep_rew_mean      | 1.45     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 895      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 12850    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 760      |
# |    ep_rew_mean      | 1.45     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 896      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 12988    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 757      |
# |    ep_rew_mean      | 1.43     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 896      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 13078    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 757      |
# |    ep_rew_mean      | 1.43     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 897      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 13168    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 754      |
# |    ep_rew_mean      | 1.42     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 898      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 13306    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 756      |
# |    ep_rew_mean      | 1.42     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 899      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 13445    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 753      |
# |    ep_rew_mean      | 1.41     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 899      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 13537    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 750      |
# |    ep_rew_mean      | 1.39     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 900      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 13629    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 750      |
# |    ep_rew_mean      | 1.39     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 901      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 13717    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 750      |
# |    ep_rew_mean      | 1.38     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 901      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 13856    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 747      |
# |    ep_rew_mean      | 1.37     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 902      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 13948    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 755      |
# |    ep_rew_mean      | 1.41     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 905      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 14260    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 752      |
# |    ep_rew_mean      | 1.39     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 906      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 14348    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 752      |
# |    ep_rew_mean      | 1.39     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 908      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 14545    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 754      |
# |    ep_rew_mean      | 1.41     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 908      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 14635    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 752      |
# |    ep_rew_mean      | 1.4      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 909      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 14753    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 754      |
# |    ep_rew_mean      | 1.41     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 910      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 14919    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 757      |
# |    ep_rew_mean      | 1.43     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 912      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 15130    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 757      |
# |    ep_rew_mean      | 1.43     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 917      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 15490    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 766      |
# |    ep_rew_mean      | 1.48     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 917      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 15582    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 763      |
# |    ep_rew_mean      | 1.47     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 918      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 15702    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 763      |
# |    ep_rew_mean      | 1.47     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 918      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 15824    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 761      |
# |    ep_rew_mean      | 1.46     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 919      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 15914    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 761      |
# |    ep_rew_mean      | 1.46     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 920      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 16050    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 760      |
# |    ep_rew_mean      | 1.45     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 921      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 16168    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 758      |
# |    ep_rew_mean      | 1.45     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 921      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 16258    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 756      |
# |    ep_rew_mean      | 1.43     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 921      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 16346    |
# ----------------------------------
# ----------------------------------
# ...
# |    time_elapsed     | 104      |
# |    total_timesteps  | 95167    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 720      |
# |    ep_rew_mean      | 1.22     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2756     |
# |    fps              | 911      |
# |    time_elapsed     | 104      |
# |    total_timesteps  | 95259    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 720      |
# |    ep_rew_mean      | 1.22     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2760     |
# |    fps              | 911      |
# |    time_elapsed     | 104      |
# |    total_timesteps  | 95374    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 720      |
# |    ep_rew_mean      | 1.22     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2764     |
# |    fps              | 911      |
# |    time_elapsed     | 104      |
# |    total_timesteps  | 95464    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 718      |
# |    ep_rew_mean      | 1.21     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2768     |
# |    fps              | 911      |
# |    time_elapsed     | 104      |
# |    total_timesteps  | 95627    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 719      |
# |    ep_rew_mean      | 1.22     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2772     |
# |    fps              | 911      |
# |    time_elapsed     | 104      |
# |    total_timesteps  | 95715    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 722      |
# |    ep_rew_mean      | 1.24     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2776     |
# |    fps              | 912      |
# |    time_elapsed     | 105      |
# |    total_timesteps  | 95880    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 722      |
# |    ep_rew_mean      | 1.24     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2780     |
# |    fps              | 912      |
# |    time_elapsed     | 105      |
# |    total_timesteps  | 95972    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 722      |
# |    ep_rew_mean      | 1.24     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2784     |
# |    fps              | 912      |
# |    time_elapsed     | 105      |
# |    total_timesteps  | 96107    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 713      |
# |    ep_rew_mean      | 1.19     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2788     |
# |    fps              | 912      |
# |    time_elapsed     | 105      |
# |    total_timesteps  | 96199    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 716      |
# |    ep_rew_mean      | 1.21     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2792     |
# |    fps              | 912      |
# |    time_elapsed     | 105      |
# |    total_timesteps  | 96364    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 708      |
# |    ep_rew_mean      | 1.16     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2796     |
# |    fps              | 912      |
# |    time_elapsed     | 105      |
# |    total_timesteps  | 96456    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 705      |
# |    ep_rew_mean      | 1.14     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2800     |
# |    fps              | 912      |
# |    time_elapsed     | 105      |
# |    total_timesteps  | 96548    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 705      |
# |    ep_rew_mean      | 1.14     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2804     |
# |    fps              | 912      |
# |    time_elapsed     | 105      |
# |    total_timesteps  | 96638    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 705      |
# |    ep_rew_mean      | 1.14     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2808     |
# |    fps              | 913      |
# |    time_elapsed     | 106      |
# |    total_timesteps  | 96799    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 703      |
# |    ep_rew_mean      | 1.13     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2812     |
# |    fps              | 913      |
# |    time_elapsed     | 106      |
# |    total_timesteps  | 96985    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 705      |
# |    ep_rew_mean      | 1.14     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2816     |
# |    fps              | 913      |
# |    time_elapsed     | 106      |
# |    total_timesteps  | 97126    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 707      |
# |    ep_rew_mean      | 1.15     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2820     |
# |    fps              | 913      |
# |    time_elapsed     | 106      |
# |    total_timesteps  | 97341    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 707      |
# |    ep_rew_mean      | 1.15     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2824     |
# |    fps              | 913      |
# |    time_elapsed     | 106      |
# |    total_timesteps  | 97463    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 708      |
# |    ep_rew_mean      | 1.16     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2828     |
# |    fps              | 913      |
# |    time_elapsed     | 106      |
# |    total_timesteps  | 97551    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 707      |
# |    ep_rew_mean      | 1.15     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2832     |
# |    fps              | 914      |
# |    time_elapsed     | 106      |
# |    total_timesteps  | 97687    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 711      |
# |    ep_rew_mean      | 1.17     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2836     |
# |    fps              | 914      |
# |    time_elapsed     | 107      |
# |    total_timesteps  | 97958    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 714      |
# |    ep_rew_mean      | 1.19     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2840     |
# |    fps              | 914      |
# |    time_elapsed     | 107      |
# |    total_timesteps  | 98044    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 714      |
# |    ep_rew_mean      | 1.19     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2844     |
# |    fps              | 914      |
# |    time_elapsed     | 107      |
# |    total_timesteps  | 98278    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 723      |
# |    ep_rew_mean      | 1.24     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2848     |
# |    fps              | 915      |
# |    time_elapsed     | 107      |
# |    total_timesteps  | 98445    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 722      |
# |    ep_rew_mean      | 1.23     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2852     |
# |    fps              | 915      |
# |    time_elapsed     | 107      |
# |    total_timesteps  | 98581    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 724      |
# |    ep_rew_mean      | 1.24     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2856     |
# |    fps              | 915      |
# |    time_elapsed     | 107      |
# |    total_timesteps  | 98841    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 733      |
# |    ep_rew_mean      | 1.32     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2860     |
# |    fps              | 915      |
# |    time_elapsed     | 108      |
# |    total_timesteps  | 99031    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 733      |
# |    ep_rew_mean      | 1.32     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2864     |
# |    fps              | 915      |
# |    time_elapsed     | 108      |
# |    total_timesteps  | 99123    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 730      |
# |    ep_rew_mean      | 1.3      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2868     |
# |    fps              | 915      |
# |    time_elapsed     | 108      |
# |    total_timesteps  | 99213    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 732      |
# |    ep_rew_mean      | 1.31     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2872     |
# |    fps              | 915      |
# |    time_elapsed     | 108      |
# |    total_timesteps  | 99351    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 731      |
# |    ep_rew_mean      | 1.3      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2876     |
# |    fps              | 915      |
# |    time_elapsed     | 108      |
# |    total_timesteps  | 99514    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 732      |
# |    ep_rew_mean      | 1.31     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2880     |
# |    fps              | 915      |
# |    time_elapsed     | 108      |
# |    total_timesteps  | 99632    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 732      |
# |    ep_rew_mean      | 1.31     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2884     |
# |    fps              | 915      |
# |    time_elapsed     | 108      |
# |    total_timesteps  | 99722    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 732      |
# |    ep_rew_mean      | 1.31     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2888     |
# |    fps              | 915      |
# |    time_elapsed     | 108      |
# |    total_timesteps  | 99814    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 732      |
# |    ep_rew_mean      | 1.31     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2892     |
# |    fps              | 915      |
# |    time_elapsed     | 109      |
# |    total_timesteps  | 99904    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 732      |
# |    ep_rew_mean      | 1.31     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2896     |
# |    fps              | 915      |
# |    time_elapsed     | 109      |
# |    total_timesteps  | 99992    |
# ----------------------------------
# Eval num_timesteps=100000, episode_reward=2.20 +/- 4.40
# Episode length: 643.80 +/- 223.71
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 644      |
# |    mean_reward      | 2.2      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 100000   |
# ----------------------------------
# Saving to /home/sequenzia/dev/rl-project/trained-agents/dqn/BreakoutNoFrameskip-v4_1
# Saving replay buffer
# wandb: WARNING No program path found, not creating job artifact. See https://docs.wandb.ai/guides/launch/create-job
# wandb:
# wandb: Run history:
# wandb:      eval/mean_ep_length ▃▃▃█▆▃▅▃▁▃
# wandb:         eval/mean_reward ▃▃▃█▆▃▆▃▁▃
# wandb:              global_step ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇████
# wandb:      rollout/ep_len_mean ▁▄▃▄▃▄▄▄▃▃▃▄▄▄▅▆▇█▆▆▆▅▄▄▅▄▄▄▄▅▄▂▃▄▃▄▃▃▂▃
# wandb:      rollout/ep_rew_mean ▁▃▃▄▃▄▄▄▄▃▃▄▄▄▅▆▇█▇▇▆▆▄▅▅▅▄▄▄▅▄▃▃▄▃▄▃▃▂▃
# wandb: rollout/exploration_rate █▆▅▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:            time/episodes ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:                 time/fps ▃█▆▆▁▃▄▅▃▃▄▄▃▃▄▅▃▃▄▄▃▃▄▄▃▄▄▄▃▃▃▄▃▃▃▄▃▃▄▄
# wandb:        time/time_elapsed ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇████
# wandb:     time/total_timesteps ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇████
# wandb:
# wandb: Run summary:
# wandb:      eval/mean_ep_length 643.79999
# wandb:         eval/mean_reward 2.2
# wandb:              global_step 100000
# wandb:      rollout/ep_len_mean 732.07001
# wandb:      rollout/ep_rew_mean 1.31
# wandb: rollout/exploration_rate 0.01
# wandb:            time/episodes 2896.0
# wandb:                 time/fps 915.0
# wandb:        time/time_elapsed 109.0
# wandb:     time/total_timesteps 100000.0
# wandb:
# wandb: 🚀 View run BreakoutNoFrameskip-v4__dqn__43__1702876785 at: https://wandb.ai/appliedtheta/Solen-RL-Project/runs/35hmzgtt
# wandb: Synced 7 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# wandb: Find logs at: ./logs/wandb/run-20231218_001945-35hmzgtt/logs
